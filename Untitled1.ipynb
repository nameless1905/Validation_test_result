# %%
# %pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.0/11.0 MB 1.4 MB/s eta 0:00:000:00:010:00:01020m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.7/16.7 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [pandas]━━━━ 1/2 [pandas]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_csv('data.csv',delimiter = ";")

# %%
df_out = df.iloc[:104]
df_out
with open('df_100.csv','w',encoding='utf-8') as f:
    df_out.to_csv(f,index=False)

# %%
df["имя_параметра"].unique()
# Out:
# <StringArray>
# [                                                        'Эритроциты',
#                                                           'Лейкоциты',
#                                                    'Нейтрофилы, абс.',
#                                                        'Лимфоциты, %',
#                                                         'Моноциты, %',
#                                                       'Эозинофилы, %',
#                                                         'Базофилы, %',
#                                           'IG - незрелые гранулоциты',
#                                                          'Гемоглобин',
#                                                          'Гематокрит',
#                'MCV (Средний объем эритроцитов в общем объеме пробы)',
#                                                     'Лимфоциты, абс.',
#                                                    'Эозинофилы, абс.',
# ...
